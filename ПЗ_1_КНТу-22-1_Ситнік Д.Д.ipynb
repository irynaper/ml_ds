# %% [markdown]
# # ПЗ №1 КНТу-22-1 Ситнік Д.Д.
# Варіант №6 - airquality

# %%
from pycaret.datasets import get_data
data = get_data('airquality')
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  2004-03-10  18:00:00     2.6         1360       150      11.9
# 1  2004-03-10  19:00:00     2.0         1292       112       9.4
# 2  2004-03-10  20:00:00     2.2         1402        88       9.0
# 3  2004-03-10  21:00:00     2.2         1376        80       9.2
# 4  2004-03-10  22:00:00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
# 2            939      131          1140      114          1555         1074
# 3            948      172          1092      122          1584         1203
# 4            836      131          1205      116          1490         1110
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %% [markdown]
# Опис полів датасету "airquality":
#
# - Date: Дата вимірювання, у форматі YYYY-MM-DD.
# - Time: Час вимірювання, у форматі HH:MM:SS.
# - CO(GT): Концентрація вуглекислого газу (CO) у мікрограмах на кубічний метр (µg/m³).
# - PT08.S1(CO): Резистивність сенсора, що вимірює концентрацію CO (прямо пропорційна концентрації CO).
# - NMHC(GT): Концентрація неполярних органічних сполук (NMHC) у мікрограмах на кубічний метр (µg/m³).
# - C6H6(GT): Концентрація бензолу (C6H6) у мікрограмах на кубічний метр (µg/m³).
# - PT08.S2(NMHC): Резистивність сенсора, що вимірює концентрацію NMHC (прямо пропорційна концентрації NMHC).
# - NOx(GT): Концентрація оксидів азоту (NOx) у мікрограмах на кубічний метр (µg/m³).
# - PT08.S3(NOx): Резистивність сенсора, що вимірює концентрацію NOx (прямо пропорційна концентрації NOx).
# - NO2(GT): Концентрація діоксиду азоту (NO2) у мікрограмах на кубічний метр (µg/m³).
# - PT08.S4(NO2): Резистивність сенсора, що вимірює концентрацію NO2 (прямо пропорційна концентрації NO2).
# - PT08.S5(O3): Резистивність сенсора, що вимірює концентрацію озону (O3) (прямо пропорційна концентрації O3).
# - T: Температура в градусах Цельсія.
# - RH: Вологість повітря (relative humidity) у відсотках (%).
# - AH: Абсолютна вологість, вимірювана в г/м³ (grams per cubic meter).

# %%
AllData = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   int64
#  4   NMHC(GT)       9357 non-null   int64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   int64
#  7   NOx(GT)        9357 non-null   int64
#  8   PT08.S3(NOx)   9357 non-null   int64
#  9   NO2(GT)        9357 non-null   int64
#  10  PT08.S4(NO2)   9357 non-null   int64
#  11  PT08.S5(O3)    9357 non-null   int64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 1.1+ MB

# %%
data['T'].hist(bins=100)
# Out:
# <Axes: >

# %% [markdown]
# ## Data Preparation

# %%
from pycaret import regression
s = regression.setup(data,
                     categorical_features = ['Date','Time'],
                     normalize = True,
                     target = 'NOx(GT)',
                     session_id = 123)
# Out:
# <style type="text/css">
# #T_e7600_row9_col1, #T_e7600_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e7600">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7600_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e7600_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7600_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7600_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e7600_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e7600_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7600_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e7600_row1_col1" class="data row1 col1" >NOx(GT)</td>
#     </tr>
#     <tr>
#       <th id="T_e7600_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
regression.get_config('X_train')
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)    C6H6(GT)  \
# 8019  2005-02-07  21:00:00     1.6          988      -200    4.500000
# 6763  2004-12-17  13:00:00     3.5         -200      -200 -200.000000
# 8880  2005-03-15  18:00:00     3.9         1413      -200   21.600000
# 4318  2004-09-06  16:00:00     1.5          996      -200    6.700000
# 9166  2005-03-27  16:00:00     1.4         1093      -200    3.500000
# ...          ...       ...     ...          ...       ...         ...
# 7382  2005-01-12   8:00:00     3.8         1478      -200   17.799999
# 7763  2005-01-28   5:00:00     0.5          818      -200    0.900000
# 5218  2004-10-14   4:00:00  -200.0          728      -200    0.800000
# 1346  2004-05-05  20:00:00     2.1         1110      -200    9.200000
# 3582  2004-08-07   0:00:00     1.4          974      -200    8.500000
#
#       PT08.S2(NMHC)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# ...

# %%
regression.get_config('X_train').columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')

# %% [markdown]
# ## Model Training & Selection

# %% [markdown]
# ## Compare Models

# %%
best = regression.compare_models(sort='MAE')
# Out:
# <style type="text/css">
# #T_24f1a th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# ExtraTreesRegressor(n_jobs=-1, random_state=123)

# %%
type(best)
# Out:
# sklearn.ensemble._forest.ExtraTreesRegressor

# %% [markdown]
# ## Create Model

# %%
dt = regression.create_model('dt')
# Out:
# <style type="text/css">
# #T_fb06b_row10_col0, #T_fb06b_row10_col1, #T_fb06b_row10_col2, #T_fb06b_row10_col3, #T_fb06b_row10_col4, #T_fb06b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_fb06b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb06b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_fb06b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_fb06b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_fb06b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_fb06b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_fb06b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
print(dt)
# Out:
# DecisionTreeRegressor(random_state=123)

# %% [markdown]
# ## Tune Hyperparameters

# %%
tuned_dt = regression.tune_model(dt, optimize = 'rmse')
# Out:
# <style type="text/css">
# #T_b2308_row10_col0, #T_b2308_row10_col1, #T_b2308_row10_col2, #T_b2308_row10_col3, #T_b2308_row10_col4, #T_b2308_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b2308">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2308_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b2308_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b2308_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b2308_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b2308_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b2308_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
print(tuned_dt)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=10, max_features=1.0,
#                       min_impurity_decrease=0.01, min_samples_leaf=2,
#                       min_samples_split=9, random_state=123)

# %% [markdown]
# ## Ensemble Model

# %%
bagged_tunned_dt = regression.ensemble_model(tuned_dt, optimize = 'rmse')
# Out:
# <style type="text/css">
# #T_9f7b7_row10_col0, #T_9f7b7_row10_col1, #T_9f7b7_row10_col2, #T_9f7b7_row10_col3, #T_9f7b7_row10_col4, #T_9f7b7_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_9f7b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f7b7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9f7b7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9f7b7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9f7b7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_9f7b7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_9f7b7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
print(bagged_tunned_dt)
# Out:
# BaggingRegressor(estimator=DecisionTreeRegressor(criterion='friedman_mse',
#                                                  max_depth=10, max_features=1.0,
#                                                  min_impurity_decrease=0.01,
#                                                  min_samples_leaf=2,
#                                                  min_samples_split=9,
#                                                  random_state=123),
#                  random_state=123)

# %% [markdown]
# ## Voting Ensemble

# %%
dt = regression.create_model('dt', verbose=False)
lasso = regression.create_model('lasso', verbose=False)
knn = regression.create_model('knn', verbose=False)

blender = regression.blend_models([dt,lasso,knn])
# Out:
# <style type="text/css">
# #T_7386f_row10_col0, #T_7386f_row10_col1, #T_7386f_row10_col2, #T_7386f_row10_col3, #T_7386f_row10_col4, #T_7386f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7386f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7386f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7386f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7386f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7386f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7386f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7386f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
print(blender)
# Out:
# VotingRegressor(estimators=[('Decision Tree Regressor',
#                              DecisionTreeRegressor(random_state=123)),
#                             ('Lasso Regression', Lasso(random_state=123)),
#                             ('K Neighbors Regressor',
#                              KNeighborsRegressor(n_jobs=-1))],
#                 n_jobs=-1)

# %%
type(blender)
# Out:
# sklearn.ensemble._voting.VotingRegressor

# %% [markdown]
# ## Stacking Ensemble

# %%
stacker = regression.stack_models([dt,lasso,knn])
# Out:
# <style type="text/css">
# #T_1005d_row10_col0, #T_1005d_row10_col1, #T_1005d_row10_col2, #T_1005d_row10_col3, #T_1005d_row10_col4, #T_1005d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1005d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1005d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1005d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1005d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1005d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1005d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1005d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
print(stacker)
# Out:
# StackingRegressor(cv=5,
#                   estimators=[('Decision Tree Regressor',
#                                DecisionTreeRegressor(random_state=123)),
#                               ('Lasso Regression', Lasso(random_state=123)),
#                               ('K Neighbors Regressor',
#                                KNeighborsRegressor(n_jobs=-1))],
#                   final_estimator=LinearRegression(n_jobs=-1), n_jobs=-1)

# %% [markdown]
# ## Analyze Model

# %%
regression.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
regression.interpret_model(dt)

# %%
regression.interpret_model(dt, plot = 'reason', observation=1)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %% [markdown]
# ## Model Predictions

# %%
pred_holdout = regression.predict_model(best);
# Out:
# <style type="text/css">
# </style>
# <table id="T_5bd27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bd27_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5bd27_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5bd27_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5bd27_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5bd27_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5bd27_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5bd27_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bd27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bd27_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_5bd27_row0_col1" class="data row0 col1" >23.8949</td>
# ...

# %%
pred_holdout.head()
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 5240  2004-10-15   2:00:00  -200.0          862      -200       3.0
# 7651  2005-01-23  13:00:00  -200.0         1160      -200       9.2
# 8959  2005-03-19   1:00:00     1.9         1192      -200       6.4
# 2095  2004-06-06   1:00:00     0.6          810      -200       3.8
# 3357  2004-07-28  15:00:00  -200.0          949      -200      10.7
#
#       PT08.S2(NMHC)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 5240            649          1046     -200          1289          675
# 7651            948           712      191          1072         1289
# 8959            832           646      155          1253         1167
# 2095            702          1093       24          1529          612
# 3357           1003           830      113          1473          730
#
#               T         RH      AH  NOx(GT)  prediction_label
# 5240  14.400000  84.599998  1.3794     -200           -200.00
# ...

# %%
data2 = data.copy()
data2.drop('NOx(GT)', axis=1, inplace=True)
data2.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  2004-03-10  18:00:00     2.6         1360       150      11.9
# 1  2004-03-10  19:00:00     2.0         1292       112       9.4
# 2  2004-03-10  20:00:00     2.2         1402        88       9.0
# 3  2004-03-10  21:00:00     2.2         1376        80       9.2
# 4  2004-03-10  22:00:00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T  \
# 0           1046          1056      113          1692         1268  13.6
# 1            955          1174       92          1559          972  13.3
# 2            939          1140      114          1555         1074  11.9
# 3            948          1092      122          1584         1203  11.0
# 4            836          1205      116          1490         1110  11.2
#
#      RH      AH
# 0  48.9  0.7578
# 1  47.7  0.7255
# 2  54.0  0.7502
# 3  60.0  0.7867
# 4  59.6  0.7888

# %%
best_final = regression.finalize_model(best)

# %%
predictions = regression.predict_model(best_final, data=data2)
predictions.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  2004-03-10  18:00:00     2.6         1360       150      11.9
# 1  2004-03-10  19:00:00     2.0         1292       112       9.4
# 2  2004-03-10  20:00:00     2.2         1402        88       9.0
# 3  2004-03-10  21:00:00     2.2         1376        80       9.2
# 4  2004-03-10  22:00:00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T  \
# 0           1046          1056      113          1692         1268  13.6
# 1            955          1174       92          1559          972  13.3
# 2            939          1140      114          1555         1074  11.9
# 3            948          1092      122          1584         1203  11.0
# 4            836          1205      116          1490         1110  11.2
#
#           RH      AH  prediction_label
# 0  48.900002  0.7578             166.0
# 1  47.700001  0.7255             103.0
# ...

# %% [markdown]
# ## Save / Load / Deploy Model

# %%
regression.save_model(best_final, 'airquality-pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['CO(GT)', 'PT08.S1(CO)',
#                                               'NMHC(GT)', 'C6H6(GT)',
#                                               'PT08.S2(NMHC)', 'PT08.S3(NOx)',
#                                               'NO2(GT)', 'PT08.S4(NO2)',
#                                               'PT08.S5(O3)', 'T', 'RH', 'AH'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Date', 'Time'],
#                                      transformer=SimpleImputer(stra...
#                                                                use_cat_names=True))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['Date'],
# ...

# %%
loaded_pipeline = regression.load_model('airquality-pipeline')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
print(loaded_pipeline)
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\dsdim\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['CO(GT)', 'PT08.S1(CO)',
#                                              'NMHC(GT)', 'C6H6(GT)',
#                                              'PT08.S2(NMHC)', 'PT08.S3(NOx)',
#                                              'NO2(GT)', 'PT08.S4(NO2)',
#                                              'PT08.S5(O3)', 'T', 'RH', 'AH'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['Date...
#                                                               use_cat_names=True))),
#                 ('rest_encoding',
#                  TransformerWrapper(include=['Date'],
#                                     transformer=TargetEncoder(cols=['Date'],
# ...

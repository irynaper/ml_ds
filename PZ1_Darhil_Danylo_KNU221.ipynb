# %% [markdown]
# # ПЗ № 1. Даргіль Данило Олександрович. КНТу-22-1. Варіант №1. Датасет NBA

# %% [markdown]
# 1. У середовищі JupiterNotebook створити новий ноутбук, імпортувати datasets з PyCaret за допомогою коду

# %%
from pycaret.datasets import get_data

# %% [markdown]
# ## Dataset

# %% [markdown]
# 2. За допомогою функції get_data завантажити dataset згідно із варіантом з таблиці 1.

# %%
Data = get_data('nba')
# Out:
#               Name  GP   MIN  PTS  FGM  FGA   FG%  3P Made  3PA   3P%  ...  \
# 0   Brandon Ingram  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  25.0  ...
# 1  Andrew Harrison  35  26.9  7.2  2.0  6.7  29.6      0.7  2.8  23.5  ...
# 2   JaKarr Sampson  74  15.3  5.2  2.0  4.7  42.2      0.4  1.7  24.4  ...
# 3      Malik Sealy  58  11.6  5.7  2.3  5.5  42.6      0.1  0.5  22.6  ...
# 4      Matt Geiger  48  11.5  4.5  1.6  3.0  52.4      0.0  0.1   0.0  ...
#
#    FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 0  2.3  69.9   0.7   3.4  4.1  1.9  0.4  0.4  1.3            0
# 1  3.4  76.5   0.5   2.0  2.4  3.7  1.1  0.5  1.6            0
# 2  1.3  67.0   0.5   1.7  2.2  1.0  0.5  0.3  1.0            0
# 3  1.3  68.9   1.0   0.9  1.9  0.8  0.6  0.1  1.0            1
# 4  1.9  67.4   1.0   1.5  2.5  0.3  0.3  0.4  0.8            1
#
# [5 rows x 21 columns]

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         1340 non-null   object
#  1   GP           1340 non-null   int64
#  2   MIN          1340 non-null   float64
#  3   PTS          1340 non-null   float64
#  4   FGM          1340 non-null   float64
#  5   FGA          1340 non-null   float64
#  6   FG%          1340 non-null   float64
#  7   3P Made      1340 non-null   float64
#  8   3PA          1340 non-null   float64
#  9   3P%          1329 non-null   float64
#  10  FTM          1340 non-null   float64
#  11  FTA          1340 non-null   float64
#  12  FT%          1340 non-null   float64
#  13  OREB         1340 non-null   float64
#  14  DREB         1340 non-null   float64
#  15  REB          1340 non-null   float64
#  16  AST          1340 non-null   float64
#  17  STL          1340 non-null   float64
# ...

# %%
Data.shape
# Out:
# (1340, 21)

# %%
Data.describe()
# Out:
#                 GP          MIN          PTS          FGM          FGA  \
# count  1340.000000  1340.000000  1340.000000  1340.000000  1340.000000
# mean     60.414179    17.624627     6.801493     2.629104     5.885299
# std      17.433992     8.307964     4.357545     1.683555     3.593488
# min      11.000000     3.100000     0.700000     0.300000     0.800000
# 25%      47.000000    10.875000     3.700000     1.400000     3.300000
# 50%      63.000000    16.100000     5.550000     2.100000     4.800000
# 75%      77.000000    22.900000     8.800000     3.400000     7.500000
# max      82.000000    40.900000    28.200000    10.200000    19.800000
#
#                FG%      3P Made          3PA          3P%          FTM  \
# count  1340.000000  1340.000000  1340.000000  1329.000000  1340.000000
# mean     44.169403     0.247612     0.779179    19.308126     1.297687
# std       6.137679     0.383688     1.061847    16.022916     0.987246
# ...

# %%
Data.TARGET_5Yrs.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data_seen = Data.sample(frac=0.9, random_state=786)
data_unseen = Data.drop(data_seen.index)

data_seen.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)

print('Data for Modeling: ' + str(data_seen.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (1206, 21)
# Unseen Data For Predictions: (134, 21)

# %% [markdown]
# 3. Для кожного датасету знайти в інтернеті опис ознак для повного розуміння фізичного сенсу даних, що ви маєте. Цей опис додати до звіту або до ноутбуку.

# %% [markdown]
# ### **Опис датасету NBA**
#
# Датасет **NBA** містить статистичні показники гравців NBA та використовується для аналізу їхньої продуктивності, а також для прогнозування майбутньої кар'єри. Основна мета – визначити, чи буде гравець залишатися в NBA через **5 років** після початкового сезону.
#
# ---
#
# #### **Загальна структура датасету**
# - **Кількість записів:** 1340 (гравці)
# - **Кількість стовпців:** 21
# - **Типи даних:**
#   - 1 текстовий (`Name` – ім'я гравця)
#   - 2 цілочислові (`GP`, `TARGET_5Yrs`)
#   - 18 числових (float) – статистичні показники гравця
#
# ---
#
# ### **Опис стовпців**
# | **Стовпець**    | **Опис** |
# |-----------------|----------|
# | **`Name`**      | Ім'я гравця. |
# | **`GP`**        | Кількість зіграних матчів (Games Played). |
# | **`MIN`**       | Середня кількість хвилин, проведених на майданчику за гру (Minutes Per Game). |
# | **`PTS`**       | Середня кількість очок за гру (Points Per Game). |
# | **`FGM`**       | Кількість влучень з гри (Field Goals Made). |
# | **`FGA`**       | Кількість спроб кидків з гри (Field Goals Attempted). |
# | **`FG%`**       | Відсоток влучань з гри (Field Goal Percentage). |
# | **`3P Made`**   | Кількість влучних триочкових кидків (Three-Point Field Goals Made). |
# | **`3PA`**       | Кількість спроб триочкових кидків (Three-Point Field Goals Attempted). |
# | **`3P%`**       | Відсоток влучань триочкових кидків (Three-Point Field Goal Percentage). |
# | **`FTM`**       | Кількість влучних штрафних кидків (Free Throws Made). |
# | **`FTA`**       | Кількість спроб штрафних кидків (Free Throws Attempted). |
# | **`FT%`**       | Відсоток влучань штрафних кидків (Free Throw Percentage). |
# | **`OREB`**      | Кількість підбирань у нападі (Offensive Rebounds). |
# | **`DREB`**      | Кількість підбирань у захисті (Defensive Rebounds). |
# | **`REB`**       | Загальна кількість підбирань (Total Rebounds). |
# | **`AST`**       | Кількість передач, що привели до результативного кидка (Assists). |
# | **`STL`**       | Кількість перехоплень м'яча (Steals). |
# | **`BLK`**       | Кількість блокшотів (Blocks). |
# | **`TOV`**       | Кількість втрат м'яча (Turnovers). |
# | **`TARGET_5Yrs`** | *Цільова змінна:* - `1` – Гравець продовжить виступати в NBA через 5 років. - `0` – Гравець не буде грати в NBA через 5 років. |
#
# ---
#
# ### **Призначення датасету**
# Датасет використовується для таких задач:
# - **Аналіз продуктивності гравців:** Визначення найкращих та найгірших показників.
# - **Прогнозування кар'єрного шляху:** Використання `TARGET_5Yrs` як цільової змінної в моделі машинного навчання для передбачення кар'єри гравців.
# - **Оцінка важливих факторів:** Виявлення ключових характеристик, які впливають на довгострокову кар'єру в NBA.

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# <pre>4. В залежності від завантаженого датасету необхідно прийняти рішення яке завдання є актуальним для вирішення: регресія, класифікація чи кластеризація. Слід зауважити, що всі датасети можуть бути оброблені багатьма способами для вирішення різноманітних завдань. В залежності від обраного завдання імпортуємо from pycaret import regression чи from pycaret import classification чи from pycaret import clustering.
#
# Для датасету за варіантом №1, а саме датасету NBA, відповідно до стовбця TARGET_5Yrs необхідно вирішити задачу класифікації. Оскільки даний стовпець містить в собі або 0 або 1, що означає чи буде гравець продовжувати свою карєру через пять років, то відповідно до даного датасету найбільш актульною задачею є задача класифікації (класифікація стовбичка до значення 1 або 0 за іншими параметрами).

# %%
from pycaret import classification
s = classification.setup(data = Data,
                         train_size = 0.9,
                         target = 'TARGET_5Yrs', 
                         session_id=123)
# Out:
# <style type="text/css">
# #T_47b08_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_47b08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47b08_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_47b08_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47b08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47b08_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_47b08_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_47b08_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47b08_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_47b08_row1_col1" class="data row1 col1" >TARGET_5Yrs</td>
#     </tr>
#     <tr>
#       <th id="T_47b08_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# check transformed X_train
classification.get_config('X_train')
# Out:
#                   Name  GP        MIN   PTS  FGM   FGA        FG%  3P Made  \
# 284    William Bedford  50  19.600000   6.7  2.8   7.2  39.700001      0.0
# 1165   Lorenzen Wright  77  25.100000   7.3  3.1   6.4  48.099998      0.0
# 1021    Gerald Wallace  54   8.000000   3.2  1.4   3.2  42.900002      0.0
# 1257       Bill Curley  53  11.200000   2.7  1.1   2.5  43.299999      0.0
# 994   Jason Richardson  80  32.900002  14.4  5.8  13.6  42.599998      1.0
# ...                ...  ..        ...   ...  ...   ...        ...      ...
# 358      Melvin Turpin  79  24.700001  10.6  4.6   9.0  51.099998      0.0
# 1202      Ashraf Amaya  54  20.400000   6.3  2.2   4.7  48.000000      0.0
# 881     Antoine Wright  39   9.500000   1.8  0.7   2.1  35.799999      0.0
# 1331      Lee Mayberry  82  18.299999   5.2  2.1   4.6  45.599998      0.5
# 163      Charles Smith  60   8.700000   2.9  1.0   2.2  44.400002      0.0
#
# ...

# %%
# list columns of transformed X_train 
classification.get_config('X_train').columns
# Out:
# Index(['Name', 'GP', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3P Made', '3PA',
#        '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
#        'TOV'],
#       dtype='object')

# %% [markdown]
# ## Model Training & Selection

# %% [markdown]
# ### Compare Models

# %% [markdown]
# 5. Проводимо аналіз даних

# %%
# check available models
classification.models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# ...

# %%
# train all models using default hyperparameters
best = classification.compare_models(exclude=['nb'], sort='F1')
# Out:
# <style type="text/css">
# #T_18344 th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
type(best)
# Out:
# sklearn.linear_model._logistic.LogisticRegression

# %% [markdown]
# ### Create Model

# %%
# train individual model
lr = classification.create_model('lr')
# Out:
# <style type="text/css">
# #T_a2ea9_row10_col0, #T_a2ea9_row10_col1, #T_a2ea9_row10_col2, #T_a2ea9_row10_col3, #T_a2ea9_row10_col4, #T_a2ea9_row10_col5, #T_a2ea9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a2ea9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2ea9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a2ea9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a2ea9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a2ea9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a2ea9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a2ea9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a2ea9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
print(lr)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
rf = classification.create_model('rf')
# Out:
# <style type="text/css">
# #T_1c5e8_row10_col0, #T_1c5e8_row10_col1, #T_1c5e8_row10_col2, #T_1c5e8_row10_col3, #T_1c5e8_row10_col4, #T_1c5e8_row10_col5, #T_1c5e8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1c5e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c5e8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1c5e8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1c5e8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1c5e8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1c5e8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1c5e8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1c5e8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
print(rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                        oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %%
knn = classification.create_model('knn')
# Out:
# <style type="text/css">
# #T_5f0a3_row10_col0, #T_5f0a3_row10_col1, #T_5f0a3_row10_col2, #T_5f0a3_row10_col3, #T_5f0a3_row10_col4, #T_5f0a3_row10_col5, #T_5f0a3_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5f0a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f0a3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5f0a3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5f0a3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5f0a3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5f0a3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5f0a3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5f0a3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
print(knn)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %% [markdown]
# ### Tune Hyperparameters

# %%
tuned_lr = classification.tune_model(lr)
# Out:
# <style type="text/css">
# #T_abf71_row10_col0, #T_abf71_row10_col1, #T_abf71_row10_col2, #T_abf71_row10_col3, #T_abf71_row10_col4, #T_abf71_row10_col5, #T_abf71_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_abf71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abf71_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_abf71_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_abf71_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_abf71_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_abf71_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_abf71_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_abf71_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
print(tuned_lr)
# Out:
# LogisticRegression(C=0.056, class_weight={}, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(lr)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
tuned_rf = classification.tune_model(rf)
# Out:
# <style type="text/css">
# #T_a008c_row10_col0, #T_a008c_row10_col1, #T_a008c_row10_col2, #T_a008c_row10_col3, #T_a008c_row10_col4, #T_a008c_row10_col5, #T_a008c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a008c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a008c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a008c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a008c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a008c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a008c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a008c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a008c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
import numpy as np
tuned_knn = classification.tune_model(knn, custom_grid = {'n_neighbors' : np.arange(0,60,1)})
# Out:
# <style type="text/css">
# #T_9178e_row10_col0, #T_9178e_row10_col1, #T_9178e_row10_col2, #T_9178e_row10_col3, #T_9178e_row10_col4, #T_9178e_row10_col5, #T_9178e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9178e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9178e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9178e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9178e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9178e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9178e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9178e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9178e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %% [markdown]
# ### Plot Model

# %% [markdown]
# 6. Не забуваємо про метрики, яким оцінюється ваш аналіз.

# %%
classification.plot_model(tuned_lr, plot = 'auc')

# %%
classification.plot_model(tuned_rf, plot='feature_all')

# %%
classification.plot_model(tuned_knn, plot = 'pr')

# %%
classification.plot_model(tuned_lr, plot = 'confusion_matrix')

# %%
classification.evaluate_model(tuned_lr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ## Prediction

# %% [markdown]
# 7. Зберігаємо всі необхідні результати у ноутбук.

# %%
classification.predict_model(tuned_lr);
# Out:
# <style type="text/css">
# </style>
# <table id="T_fe322">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe322_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fe322_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fe322_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fe322_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fe322_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fe322_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fe322_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fe322_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe322_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe322_row0_col0" class="data row0 col0" >Logistic Regression</td>
# ...

# %%
final_lr = classification.finalize_model(tuned_lr)

print(final_lr)
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['GP', 'MIN', 'PTS', 'FGM', 'FGA',
#                                              'FG%', '3P Made', '3PA', '3P%',
#                                              'FTM', 'FTA', 'FT%', 'OREB',
#                                              'DREB', 'REB', 'AST', 'STL', 'BLK',
#                                              'TOV'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strateg...
# ...

# %%
classification.predict_model(final_lr);
# Out:
# <style type="text/css">
# </style>
# <table id="T_48698">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48698_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_48698_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_48698_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_48698_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_48698_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_48698_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_48698_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_48698_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48698_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48698_row0_col0" class="data row0 col0" >Logistic Regression</td>
# ...

# %%
unseen_predictions = classification.predict_model(final_lr, data=data_unseen)
unseen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_512f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_512f4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_512f4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_512f4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_512f4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_512f4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_512f4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_512f4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_512f4_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_512f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_512f4_row0_col0" class="data row0 col0" >Logistic Regression</td>
# ...

# %%
unseen_predictions[unseen_predictions['prediction_score'] > 0.9]
# Out:
#                 Name  GP        MIN   PTS  FGM   FGA        FG%  3P Made  3PA  \
# 30    Brad Daugherty  80  33.700001  15.7  6.1  11.3  53.799999      0.0  0.0
# 35   Benoit Benjamin  79  26.400000  11.1  4.1   8.4  49.000000      0.0  0.0
# 48       Rod Higgins  82  26.799999  10.3  3.8   8.5  44.799999      0.2  0.5
# 53       Jay Vincent  81  32.400002  21.4  8.9  17.9  49.700001      0.0  0.0
# 131   LaPhonso Ellis  82  33.500000  14.7  5.9  11.7  50.400002      0.0  0.2
#
#            3P%  ...  OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs  \
# 30    0.000000  ...   1.9   6.2  8.1  3.8  0.6  0.8  3.1            1
# 35   33.299999  ...   2.0   5.6  7.6  1.0  0.8  2.6  1.8            1
# 48   31.700001  ...   1.9   2.5  4.5  2.1  0.8  0.8  1.6            1
# 53   25.000000  ...   2.2   4.7  7.0  2.2  1.1  0.3  2.4            1
# 131  15.400000  ...   3.3   5.7  9.1  1.8  0.9  1.4  1.9            1
#
#      prediction_label  prediction_score
# ...

# %% [markdown]
# ## Save model

# %% [markdown]
# 8. Зберігаємо модель в файл формату .pkl

# %%
classification.save_model(final_lr,'final_lr_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['GP', 'MIN', 'PTS', 'FGM', 'FGA',
#                                               'FG%', '3P Made', '3PA', '3P%',
#                                               'FTM', 'FTA', 'FT%', 'OREB',
#                                               'DREB', 'REB', 'AST', 'STL', 'BLK',
#                                               'TOV'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
# ...

# %%
saved_final_lr = classification.load_model('final_lr_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_prediction = classification.predict_model(saved_final_lr, data=data_unseen)
new_prediction.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_aa009">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa009_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_aa009_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_aa009_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_aa009_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_aa009_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_aa009_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_aa009_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_aa009_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa009_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aa009_row0_col0" class="data row0 col0" >Logistic Regression</td>
# ...
